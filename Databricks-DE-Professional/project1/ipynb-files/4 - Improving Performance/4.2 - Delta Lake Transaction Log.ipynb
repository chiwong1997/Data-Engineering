# %%
# %run ../Includes/Copy-Datasets

# %% [markdown]
# Lets take a look at the delta logs for the bronze table

# %%
files = dbutils.fs.ls("dbfs:/user/hive/warehouse/bookstore_eng_pro.db/bronze/_delta_log")
display(files)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Lets take a look at one of the transaction log files, and look at the statistics

# %%
display(spark.read.json("dbfs:/user/hive/warehouse/bookstore_eng_pro.db/bronze/_delta_log/00000000000000000001.json"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# This is really useful because it you are filtering for an offset that has a greater offset than that of the maximum value in, delta lake will just skip this file completely. If you look at row 4, and look at the summary statistics, we see that the maximum value for offset is 618831, so if we are querying, and we are looking for an offset greater than 618831, then this file will be skipped completely because the offset we are querying for is less than the maximum offset for this data file

# %%
# %sql
SELECT COUNT(*) FROM bronze
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>8036</td></tr></tbody></table></div>

# %% [markdown]
# Lets take a look at the transaction log checkpoints - the parquet files that are created every 10 json files

# %%
files = dbutils.fs.ls("dbfs:/user/hive/warehouse/bookstore_eng_pro.db/bronze/_delta_log")
display(files)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.read.parquet("dbfs:/user/hive/warehouse/bookstore_eng_pro.db/bronze/_delta_log/00000000000000000010.checkpoint.parquet"))
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7401517899770341>, line 1
# ----> 1 display(spark.read.parquet("dbfs:/user/hive/warehouse/bookstore_eng_pro.db/bronze/_delta_log/00000000000000000010.checkpoint.parquet"))
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/sql/readwriter.py:544, in DataFrameReader.parquet(self, *paths, **options)
#     533 int96RebaseMode = options.get("int96RebaseMode", None)
#     534 self._set_opts(
#     535     mergeSchema=mergeSchema,
# ...
